# %%
 # !pip install matplotlib.pylot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement matplotlib.pylot (from versions: none)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# ERROR: No matching distribution found for matplotlib.pylot

# %%
import pandas as pd
import matplotlib.pyplot as plt


dataset = pd.read_csv("precios.csv")
dataset["indice_tiempo"] = pd.to_datetime(dataset["indice_tiempo"], format="%Y-%m")

años = dataset[ dataset["indice_tiempo"].dt.year == 2017 ]
años
# Out:
#       indice_tiempo  idempresa           cuit                 empresa  \
# 202      2017-12-01        348  30-60588371-7  ABELLA Y ALONSO S.R.L.
# 203      2017-12-01        348  30-60588371-7  ABELLA Y ALONSO S.R.L.
# 204      2017-12-01        348  30-60588371-7  ABELLA Y ALONSO S.R.L.
# 205      2017-12-01        348  30-60588371-7  ABELLA Y ALONSO S.R.L.
# 206      2017-12-01        348  30-60588371-7  ABELLA Y ALONSO S.R.L.
# ...             ...        ...            ...                     ...
# 36768    2017-03-01       8751  30-70928426-2   YUNKA COMBUSTIBLES SA
# 36769    2017-03-01       8751  30-70928426-2   YUNKA COMBUSTIBLES SA
# 36770    2017-03-01       8751  30-70928426-2   YUNKA COMBUSTIBLES SA
# 36771    2017-03-01       8751  30-70928426-2   YUNKA COMBUSTIBLES SA
# 36772    2017-03-01       8751  30-70928426-2   YUNKA COMBUSTIBLES SA
#
#                       direccion         localidad     provincia    region  \
# 202                 MORENO 1701  VILLA  BALLESTER  BUENOS AIRES  PAMPEANA
# 203                 MORENO 1701  VILLA  BALLESTER  BUENOS AIRES  PAMPEANA
# 204                 MORENO 1701  VILLA  BALLESTER  BUENOS AIRES  PAMPEANA
# 205                 MORENO 1701  VILLA  BALLESTER  BUENOS AIRES  PAMPEANA
# 206                 MORENO 1701  VILLA  BALLESTER  BUENOS AIRES  PAMPEANA
# ...                         ...               ...           ...       ...
# 36768  av napoleon uriburu 1615           FORMOSA       FORMOSA       NEA
# 36769  av napoleon uriburu 1615           FORMOSA       FORMOSA       NEA
# 36770  av napoleon uriburu 1615           FORMOSA       FORMOSA       NEA
# 36771  av napoleon uriburu 1615           FORMOSA       FORMOSA       NEA
# 36772  av napoleon uriburu 1615           FORMOSA       FORMOSA       NEA
#
#        idproducto                          producto  idtipohorario  \
# 202            19                   Gas Oil Grado 2              2
# 203            19                   Gas Oil Grado 2              3
# 204            21                   Gas Oil Grado 3              2
# 205            21                   Gas Oil Grado 3              3
# 206             3  Nafta (premium) de más de 95 Ron              2
# ...           ...                               ...            ...
# 36768          21                   Gas Oil Grado 3              3
# 36769           3  Nafta (premium) de más de 95 Ron              2
# 36770           3  Nafta (premium) de más de 95 Ron              3
# 36771           2   Nafta (súper) entre 92 y 95 Ron              2
# 36772           2   Nafta (súper) entre 92 y 95 Ron              3
#
#       tipohorario  precio       fecha_vigencia  idempresabandera  \
# 202        Diurno   22.99  2017-12-06 11:34:00                 1
# 203      Nocturno   22.99  2017-12-06 11:34:00                 1
# 204        Diurno   25.99  2017-12-06 11:35:00                 1
# 205      Nocturno   25.99  2017-12-06 11:35:00                 1
# 206        Diurno   27.99  2017-12-06 11:36:00                 1
# ...           ...     ...                  ...               ...
# 36768    Nocturno   22.40  2017-03-29 08:56:00                 1
# 36769      Diurno   21.65  2017-03-29 08:57:00                 1
# 36770    Nocturno   21.65  2017-03-29 08:57:00                 1
# 36771      Diurno   23.85  2017-03-29 08:57:00                 1
# 36772    Nocturno   23.85  2017-03-29 08:57:00                 1
#
#       empresabandera    latitud   longitud  \
# 202           BLANCA -34.533377 -58.557665
# 203           BLANCA -34.533377 -58.557665
# 204           BLANCA -34.533377 -58.557665
# 205           BLANCA -34.533377 -58.557665
# 206           BLANCA -34.533377 -58.557665
# ...              ...        ...        ...
# 36768         BLANCA -26.195950 -58.179330
# 36769         BLANCA -26.195950 -58.179330
# 36770         BLANCA -26.195950 -58.179330
# 36771         BLANCA -26.195950 -58.179330
# 36772         BLANCA -26.195950 -58.179330
#
#                                                  geojson
# 202    {"type":"Point","coordinates":[-58.557665,-34....
# 203    {"type":"Point","coordinates":[-58.557665,-34....
# 204    {"type":"Point","coordinates":[-58.557665,-34....
# 205    {"type":"Point","coordinates":[-58.557665,-34....
# 206    {"type":"Point","coordinates":[-58.557665,-34....
# ...                                                  ...
# 36768  {"type":"Point","coordinates":[-58.17933,-26.1...
# 36769  {"type":"Point","coordinates":[-58.17933,-26.1...
# 36770  {"type":"Point","coordinates":[-58.17933,-26.1...
# 36771  {"type":"Point","coordinates":[-58.17933,-26.1...
# 36772  {"type":"Point","coordinates":[-58.17933,-26.1...
#
# [536 rows x 19 columns]

# %%
agrupacion_mes = dataset.groupby(dataset["indice_tiempo"].dt.to_period("M")).size()
agrupacion_mes
# Out:
# indice_tiempo
# 2016-06        4
# 2016-08        2
# 2017-01       44
# 2017-02       59
# 2017-03      159
#            ...
# 2025-04      869
# 2025-05     1319
# 2025-06    14065
# 2025-07     4054
# 2025-08    10244
# Freq: M, Length: 102, dtype: int64

# %%
plt.figure(figsize=(15, 8))
plt.bar(agrupacion_mes.index.astype(str),agrupacion_mes.values)
plt.title("agrupacion_mes")
plt.xlabel("mes")
plt.ylabel("ello por mes")
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
