# %% [markdown]
# # Actividad 9
# # 🔍 Parte 2: Análisis de Datasets
# Objetivo: Analizar datasets con Pandas, utilizando filtros y visualización con:
# * tablas
# * gráficos
# * mapas

# %% [markdown]
# ## Elegí un dataset
# * Realizar exploración básica

# %% [markdown]
# *  ### Avistajes de felinos en Argentina
#     * Link para descarga: https://archivos.linti.unlp.edu.ar/index.php/s/5iC9FrYWiGi11d0
#     * Nombre del archivo: felinos_filtrado.csv
#     * Descargado y adaptado de: https://www.gbif.org/
#     * Descripción: describe los avistajes de felinos en peligro de extinción con ubicación, especie, fecha etc.
# * ### Áreas protegidas
#     * Link para descarga: https://archivos.linti.unlp.edu.ar/index.php/s/Eqw1eAVC1pdefmb
#     * Descargado de: https://dnsg.ign.gob.ar/apps/api/v1/capas-sig/Geodesia+y+demarcaci%C3%B3n/L%C3%ADmites/area_protegida/csv*
#     * Página consultada: https://www.ign.gob.ar/NuestrasActividades/InformacionGeoespacial/CapasSIG
#     * Descripción: detalle de las áreas protegidas terrestres y marítimas
#     * Documento con detalle de los datos: https://archivos.linti.unlp.edu.ar/index.php/s/9LoXcqzxI8bDzbN
# * ### Aeropuertos Argentina
#     * Link para  descarga: https://archivos.linti.unlp.edu.ar/index.php/s/TYVZ5U6HC457M1k
#     * Nombre del archivo: ar-airports.csv
#     * Descargado de: https://ourairports.com/countries/AR/airports.csv
#     * Descripción: Aeropuertos de Argentina por tipo y localidad
# * ### Conectividad Argentina
#     * Link para descarga: https://archivos.linti.unlp.edu.ar/index.php/s/3k2TO5sSzaAU6IY
#     * Nombre del archivo: Conectividad_Internet.csv
#     * Descargado de : https://datos.gob.ar/dataset/enacom-conectividad-al-servicio-internet/archivo/enacom_CONEC-AL-SERVI-DE-INTER_0
#     * Descripción: Describe las tecnologías disponibles en las localidades para acceder al servicio de Internet fijo y móvil
# * ### Precios combustibles
#     * [Link para descarga](https://archivos.linti.unlp.edu.ar/index.php/s/x0InilFLhgt1B1R).
#     * Descargado de: https://www.datos.gob.ar/dataset/energia-precios-surtidor---resolucion-3142016
#     * Descripción: Datos del Sistema en línea de información de precios de combustibles en surtidor, a través del cual los titulares de bocas de expendio de combustibles líquidos inscriptos en el registro creado por la resolución n° 1.102/2004 presentan la información relativa a precios de comercialización minorista dentro de las 8 (ocho) horas de producida una modificación en el precio en surtidor.
# * ### Ferrocarriles.
#     *  [Link para descarga](https://archivos.linti.unlp.edu.ar/index.php/s/Pr6vcKL9fxfmZoj)
#     * Descargado de :https://datos.transporte.gob.ar/dataset/cruces-ferroviarios
#     * Descripción: Cruces ferroviarios con respecto a la red vial nacional. Relevados por la Dirección Nacional de Vialidad. Año 2016.

# %% [markdown]
# # ✅ Etapa 1: Exploración Básica (10 min)
# * Cantidad de filas y columans
# * Nombres de las columnas
# * Tipos de datos de las columnas
# * Ver las primeras 10 filas del dataset

# %%
import pandas as pd 
import plotly.express as pl
precio=pd.read_csv("precios.csv")

# %%
precio.shape# muestra las columnas y filas
# Out:
# (36963, 19)

# %%
precio.columns#te muestra cada columna como se llama
# Out:
# Index(['indice_tiempo', 'idempresa', 'cuit', 'empresa', 'direccion',
#        'localidad', 'provincia', 'region', 'idproducto', 'producto',
#        'idtipohorario', 'tipohorario', 'precio', 'fecha_vigencia',
#        'idempresabandera', 'empresabandera', 'latitud', 'longitud', 'geojson'],
#       dtype='object')

# %%
precio.dtypes# este te muestra los tipos de datos
# Out:
# indice_tiempo        object
# idempresa             int64
# cuit                 object
# empresa              object
# direccion            object
# localidad            object
# provincia            object
# region               object
# idproducto            int64
# producto             object
# idtipohorario         int64
# tipohorario          object
# precio              float64
# fecha_vigencia       object
# idempresabandera      int64
# empresabandera       object
# latitud             float64
# longitud            float64
# geojson              object
# dtype: object

# %%
precio.head(10)# me muestra las primeras 10 columnas
# Out:
#   indice_tiempo  idempresa           cuit               empresa  \
# 0       2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 1       2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 2       2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 3       2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 4       2025-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 5       2025-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 6       2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 7       2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 8       2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 9       2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
#
#          direccion          localidad     provincia    region  idproducto  \
# 0  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          19
# 1  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          19
# 2  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          21
# 3  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          21
# 4  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA           6
# 5  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA           6
# 6  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA           3
# 7  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA           3
# 8  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA           2
# 9  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA           2
#
#                            producto  idtipohorario tipohorario  precio  \
# 0                   Gas Oil Grado 2              2      Diurno  1338.0
# 1                   Gas Oil Grado 2              3    Nocturno  1338.0
# 2                   Gas Oil Grado 3              2      Diurno  1552.0
# 3                   Gas Oil Grado 3              3    Nocturno  1552.0
# 4                               GNC              2      Diurno   499.9
# 5                               GNC              3    Nocturno   499.9
# 6  Nafta (premium) de más de 95 Ron              2      Diurno  1617.0
# 7  Nafta (premium) de más de 95 Ron              3    Nocturno  1617.0
# 8   Nafta (súper) entre 92 y 95 Ron              2      Diurno  1340.0
# 9   Nafta (súper) entre 92 y 95 Ron              3    Nocturno  1340.0
#
#         fecha_vigencia  idempresabandera empresabandera    latitud   longitud  \
# 0  2025-06-21 09:41:00                28           PUMA -34.658476 -58.529443
# 1  2025-06-21 09:41:00                28           PUMA -34.658476 -58.529443
# 2  2025-06-21 09:41:00                28           PUMA -34.658476 -58.529443
# 3  2025-06-21 09:41:00                28           PUMA -34.658476 -58.529443
# 4  2025-05-30 12:05:00                28           PUMA -34.658476 -58.529443
# 5  2025-05-30 12:05:00                28           PUMA -34.658476 -58.529443
# 6  2025-06-21 09:42:00                28           PUMA -34.658476 -58.529443
# 7  2025-06-21 09:42:00                28           PUMA -34.658476 -58.529443
# 8  2025-06-21 09:42:00                28           PUMA -34.658476 -58.529443
# 9  2025-06-21 09:42:00                28           PUMA -34.658476 -58.529443
#
#                                              geojson
# 0  {"type":"Point","coordinates":[-58.529443,-34....
# 1  {"type":"Point","coordinates":[-58.529443,-34....
# 2  {"type":"Point","coordinates":[-58.529443,-34....
# 3  {"type":"Point","coordinates":[-58.529443,-34....
# 4  {"type":"Point","coordinates":[-58.529443,-34....
# 5  {"type":"Point","coordinates":[-58.529443,-34....
# 6  {"type":"Point","coordinates":[-58.529443,-34....
# 7  {"type":"Point","coordinates":[-58.529443,-34....
# 8  {"type":"Point","coordinates":[-58.529443,-34....
# 9  {"type":"Point","coordinates":[-58.529443,-34....

# %% [markdown]
# # ✅ Etapa 2: Análisis por temática(10 min)
# * Cada dataset se analizará según categorías correspondiente a los datos que lo conforman

# %%
precio
# Out:
#       indice_tiempo  idempresa           cuit               empresa  \
# 0           2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 1           2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 2           2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 3           2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 4           2025-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# ...             ...        ...            ...                   ...
# 36958       2024-12       4097  30-70795820-7           ZUSICO S.A.
# 36959       2025-08       4097  30-70795820-7           ZUSICO S.A.
# 36960       2025-08       4097  30-70795820-7           ZUSICO S.A.
# 36961       2025-08       4097  30-70795820-7           ZUSICO S.A.
# 36962       2025-08       4097  30-70795820-7           ZUSICO S.A.
#
#              direccion          localidad     provincia    region  idproducto  \
# 0      Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          19
# 1      Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          19
# 2      Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          21
# 3      Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          21
# 4      Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA           6
# ...                ...                ...           ...       ...         ...
# 36958  TALCAHUANO 1198      MAR DEL PLATA  BUENOS AIRES  PAMPEANA           6
# 36959  TALCAHUANO 1198      MAR DEL PLATA  BUENOS AIRES  PAMPEANA           3
# 36960  TALCAHUANO 1198      MAR DEL PLATA  BUENOS AIRES  PAMPEANA           3
# 36961  TALCAHUANO 1198      MAR DEL PLATA  BUENOS AIRES  PAMPEANA           2
# 36962  TALCAHUANO 1198      MAR DEL PLATA  BUENOS AIRES  PAMPEANA           2
#
#                                producto  idtipohorario tipohorario  precio  \
# 0                       Gas Oil Grado 2              2      Diurno  1338.0
# 1                       Gas Oil Grado 2              3    Nocturno  1338.0
# 2                       Gas Oil Grado 3              2      Diurno  1552.0
# 3                       Gas Oil Grado 3              3    Nocturno  1552.0
# 4                                   GNC              2      Diurno   499.9
# ...                                 ...            ...         ...     ...
# 36958                               GNC              3    Nocturno   779.0
# 36959  Nafta (premium) de más de 95 Ron              2      Diurno  1757.0
# 36960  Nafta (premium) de más de 95 Ron              3    Nocturno  1757.0
# 36961   Nafta (súper) entre 92 y 95 Ron              2      Diurno  1485.0
# 36962   Nafta (súper) entre 92 y 95 Ron              3    Nocturno  1485.0
#
#             fecha_vigencia  idempresabandera empresabandera    latitud  \
# 0      2025-06-21 09:41:00                28           PUMA -34.658476
# 1      2025-06-21 09:41:00                28           PUMA -34.658476
# 2      2025-06-21 09:41:00                28           PUMA -34.658476
# 3      2025-06-21 09:41:00                28           PUMA -34.658476
# 4      2025-05-30 12:05:00                28           PUMA -34.658476
# ...                    ...               ...            ...        ...
# 36958  2024-12-31 14:00:00                28           PUMA -38.031169
# 36959  2025-08-02 09:00:00                28           PUMA -38.031169
# 36960  2025-08-02 09:00:00                28           PUMA -38.031169
# 36961  2025-08-02 09:00:00                28           PUMA -38.031169
# 36962  2025-08-02 09:00:00                28           PUMA -38.031169
#
#         longitud                                            geojson
# 0     -58.529443  {"type":"Point","coordinates":[-58.529443,-34....
# 1     -58.529443  {"type":"Point","coordinates":[-58.529443,-34....
# 2     -58.529443  {"type":"Point","coordinates":[-58.529443,-34....
# 3     -58.529443  {"type":"Point","coordinates":[-58.529443,-34....
# 4     -58.529443  {"type":"Point","coordinates":[-58.529443,-34....
# ...          ...                                                ...
# 36958 -57.575518  {"type":"Point","coordinates":[-57.575518,-38....
# 36959 -57.575518  {"type":"Point","coordinates":[-57.575518,-38....
# 36960 -57.575518  {"type":"Point","coordinates":[-57.575518,-38....
# 36961 -57.575518  {"type":"Point","coordinates":[-57.575518,-38....
# 36962 -57.575518  {"type":"Point","coordinates":[-57.575518,-38....
#
# [36963 rows x 19 columns]

# %%
precio['tipohorario'].value_counts()#filtro los datos univos de la columna tipohorario
# Out:
# tipohorario
# Nocturno    18482
# Diurno      18481
# Name: count, dtype: int64

# %% [markdown]
# # ✅ Etapa 3: Filtrar y Limpiar Datos (15 min)

# %%
precio["provincia"].value_counts()#muestra los dat
# Out:
# provincia
# BUENOS AIRES           13926
# CORDOBA                 4516
# SANTA FE                3718
# ENTRE RIOS              1670
# CAPITAL FEDERAL         1640
# MENDOZA                 1494
# TUCUMAN                 1060
# RIO NEGRO                838
# MISIONES                 780
# SANTIAGO DEL ESTERO      773
# CORRIENTES               742
# LA PAMPA                 670
# SALTA                    648
# CHACO                    646
# CHUBUT                   574
# NEUQUEN                  568
# SAN JUAN                 564
# SAN LUIS                 490
# JUJUY                    412
# SANTA CRUZ               294
# CATAMARCA                286
# FORMOSA                  278
# LA RIOJA                 266
# TIERRA DEL FUEGO         110
# Name: count, dtype: int64

# %%
horario=precio[precio['provincia']=="SANTA CRUZ"]
horario
#los que estoy haciendo aca es frictrar la columna probincia dos los datos igual a santa cruz
# Out:
#       indice_tiempo  idempresa           cuit      empresa  \
# 1268        2025-06       1520  30-64298643-7  ALMA S.R.L.
# 1269        2025-06       1520  30-64298643-7  ALMA S.R.L.
# 1270        2025-06       1520  30-64298643-7  ALMA S.R.L.
# 1271        2025-06       1520  30-64298643-7  ALMA S.R.L.
# 1272        2025-06       1520  30-64298643-7  ALMA S.R.L.
# ...             ...        ...            ...          ...
# 36156       2025-07       2514  30-67373909-8  VERTAS S.A.
# 36157       2025-07       2514  30-67373909-8  VERTAS S.A.
# 36158       2025-07       2514  30-67373909-8  VERTAS S.A.
# 36159       2025-07       2514  30-67373909-8  VERTAS S.A.
# 36160       2025-07       2514  30-67373909-8  VERTAS S.A.
#
#                              direccion        localidad   provincia  \
# 1268   ANTARTIDA ARGENTINA Y RUTA 40 .  28 DE NOVIEMBRE  SANTA CRUZ
# 1269   ANTARTIDA ARGENTINA Y RUTA 40 .  28 DE NOVIEMBRE  SANTA CRUZ
# 1270   ANTARTIDA ARGENTINA Y RUTA 40 .  28 DE NOVIEMBRE  SANTA CRUZ
# 1271   ANTARTIDA ARGENTINA Y RUTA 40 .  28 DE NOVIEMBRE  SANTA CRUZ
# 1272   ANTARTIDA ARGENTINA Y RUTA 40 .  28 DE NOVIEMBRE  SANTA CRUZ
# ...                                ...              ...         ...
# 36156                   SAN MARTIN 590    CALETA OLIVIA  SANTA CRUZ
# 36157                   SAN MARTIN 590    CALETA OLIVIA  SANTA CRUZ
# 36158                   SAN MARTIN 590    CALETA OLIVIA  SANTA CRUZ
# 36159                   SAN MARTIN 590    CALETA OLIVIA  SANTA CRUZ
# 36160                   SAN MARTIN 590    CALETA OLIVIA  SANTA CRUZ
#
#           region  idproducto                          producto  idtipohorario  \
# 1268   PATAGONIA          19                   Gas Oil Grado 2              2
# 1269   PATAGONIA          19                   Gas Oil Grado 2              3
# 1270   PATAGONIA          21                   Gas Oil Grado 3              2
# 1271   PATAGONIA          21                   Gas Oil Grado 3              3
# 1272   PATAGONIA           3  Nafta (premium) de más de 95 Ron              2
# ...          ...         ...                               ...            ...
# 36156  PATAGONIA          21                   Gas Oil Grado 3              3
# 36157  PATAGONIA           3  Nafta (premium) de más de 95 Ron              2
# 36158  PATAGONIA           3  Nafta (premium) de más de 95 Ron              3
# 36159  PATAGONIA           2   Nafta (súper) entre 92 y 95 Ron              2
# 36160  PATAGONIA           2   Nafta (súper) entre 92 y 95 Ron              3
#
#       tipohorario  precio       fecha_vigencia  idempresabandera  \
# 1268       Diurno  1264.0  2025-06-01 00:00:00                 2
# 1269     Nocturno  1264.0  2025-06-01 00:00:00                 2
# 1270       Diurno  1440.0  2025-06-01 00:00:00                 2
# 1271     Nocturno  1440.0  2025-06-01 00:00:00                 2
# 1272       Diurno  1247.0  2025-06-01 00:00:00                 2
# ...           ...     ...                  ...               ...
# 36156    Nocturno  1633.0  2025-07-16 14:18:00                26
# 36157      Diurno  1406.0  2025-07-16 14:19:00                26
# 36158    Nocturno  1406.0  2025-07-16 14:19:00                26
# 36159      Diurno  1053.0  2025-07-16 14:18:00                26
# 36160    Nocturno  1053.0  2025-07-16 14:18:00                26
#
#       empresabandera   latitud  longitud  \
# 1268             YPF -51.57546 -72.21239
# 1269             YPF -51.57546 -72.21239
# 1270             YPF -51.57546 -72.21239
# 1271             YPF -51.57546 -72.21239
# 1272             YPF -51.57546 -72.21239
# ...              ...       ...       ...
# 36156          AXION -46.44170 -67.51730
# 36157          AXION -46.44170 -67.51730
# 36158          AXION -46.44170 -67.51730
# 36159          AXION -46.44170 -67.51730
# 36160          AXION -46.44170 -67.51730
#
#                                                  geojson
# 1268   {"type":"Point","coordinates":[-72.21239,-51.5...
# 1269   {"type":"Point","coordinates":[-72.21239,-51.5...
# 1270   {"type":"Point","coordinates":[-72.21239,-51.5...
# 1271   {"type":"Point","coordinates":[-72.21239,-51.5...
# 1272   {"type":"Point","coordinates":[-72.21239,-51.5...
# ...                                                  ...
# 36156  {"type":"Point","coordinates":[-67.5173,-46.44...
# 36157  {"type":"Point","coordinates":[-67.5173,-46.44...
# 36158  {"type":"Point","coordinates":[-67.5173,-46.44...
# 36159  {"type":"Point","coordinates":[-67.5173,-46.44...
# 36160  {"type":"Point","coordinates":[-67.5173,-46.44...
#
# [294 rows x 19 columns]

# %%
horario=precio[precio['provincia']=="SANTA CRUZ"]
horario['tipohorario'].value_counts()
#en este me muestre el horari de solamente santa cruz
# Out:
# tipohorario
# Diurno      147
# Nocturno    147
# Name: count, dtype: int64

# %% [markdown]
# # ✅ Etapa 4: Valores Nulos y Estadísticas (10 min)
# * Mostrar la composición de las columnas indicando aquellas con datos faltantes

# %%
precio.columns
# Out:
# Index(['indice_tiempo', 'idempresa', 'cuit', 'empresa', 'direccion',
#        'localidad', 'provincia', 'region', 'idproducto', 'producto',
#        'idtipohorario', 'tipohorario', 'precio', 'fecha_vigencia',
#        'idempresabandera', 'empresabandera', 'latitud', 'longitud', 'geojson'],
#       dtype='object')

# %%
precio.describe()#hace quee te aparesca el valor min y max numerica
# Out:
#           idempresa    idproducto  idtipohorario        precio  \
# count  36963.000000  36963.000000   36963.000000  36963.000000
# mean    5503.568136     10.730595       2.500014   1263.346597
# std     3400.661320      8.476916       0.500007    420.636036
# min      104.000000      2.000000       2.000000      6.999000
# 25%     2289.000000      3.000000       2.000000   1239.000000
# 50%     5693.000000      6.000000       3.000000   1397.000000
# 75%     8408.000000     19.000000       3.000000   1498.500000
# max    11297.000000     21.000000       3.000000   2000.000000
#
#        idempresabandera       latitud      longitud
# count      36963.000000  36867.000000  36867.000000
# mean           8.929172    -33.417297    -61.602035
# std           10.767544      4.107399      3.623024
# min           -1.000000    -54.829501    -72.338930
# 25%            2.000000    -34.800850    -64.267710
# 50%            4.000000    -34.065390    -60.670060
# 75%           26.000000    -31.444160    -58.555146
# max           30.000000    -22.055820    -53.648260

# %% [markdown]
# # ✅ Etapa 5: Visualización con Mapas (15 min)

# %% [markdown]
# *  ### Avistajes de felinos en Argentina
#     * **Mapa**: mostrar iconos de color según el tipo de "genus" .
# * ### Áreas protegidas
#     * **Mapa**: mostrar iconos de color según el tipo de área protegida definida en la columna "tap" que indica (Parque, Reserva, MonumentosNatural).
# * ### Aeropuertos Argentina
#     * **Mapa**: mostrar iconos de color según el tipo de aeropuerto: type
# * ### Conectividad Argentina
#     * **Mapa**: mostrar las localidades donde hay FIBRAOPTICA.
# * ### Precios combustibles
#     *  **Mapa**: mostrar los registros de las provincias de la Patagonia según "tipohorario".
# * ### Ferrocarriles.
#     * **Mapa**: mostrar las estaciones en el mapa según el tipo indicado en la columna "gna".

# %% [markdown]
# ## 📌 Paso 1.Generar un mapa **base** para luego agregar los puntos

# %%
precios_reb = precio.dropna(subset=["latitud","longitud"])
precios_reb = precios_reb[precios_reb['provincia']=="SANTA CRUZ"]

# %%
import folium

# %%
def generar_mapa():#funcion 
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
    )
    
    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = folium.Map(
        location=(-33.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

# %% [markdown]
# ## 📌 Paso 2. Definir la función para  agregar los puntos

# %%
def agregar_marca_lago(row):
    folium.Marker(
        [row['latitud'], row['longitud']],
        popup=row['tipohorario'],
        icon=folium.Icon()
        ).add_to(mapa)

# %%
horario=precio["latitud"].value_counts()

# %%
horario=precio["longitud"].value_counts()

# %% [markdown]
# ## 📌 Paso 3. Agrergar los puntos al mapa

# %%
mapa = generar_mapa()
precios_reb.apply(agregar_marca_lago, axis=1)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd75e6bddaaf5f5173ff7df1521cb30c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd75e6bddaaf5f5173ff7df1521cb30c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd75e6bddaaf5f5173ff7df1521cb30c = L.map(
#                 &quot;map_fd75e6bddaaf5f5173ff7df1521cb30c&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;name&quot;: &quot;es&quot;,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_fd75e6bddaaf5f5173ff7df1521cb30c);
#
#
#
#
#
#             var tile_layer_d6acac20e156d091ee23b087cb6d0586 = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d6acac20e156d091ee23b087cb6d0586.addTo(map_fd75e6bddaaf5f5173ff7df1521cb30c);
#
#
#             var marker_56df55927a625f432d11dca1a4dbf720 = L.marker(
#                 [-51.57546, -72.21239],
#                 {
# }
#             ).addTo(map_fd75e6bddaaf5f5173ff7df1521cb30c);
#
#
#             var icon_1dd048f03bb2dc114f09d9f0a34eacb3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2cb099b22641a140e6094621bcdacba3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25d49b3d1517491a11b8980b0546e43a = $(`&lt;div id=&quot;html_25d49b3d1517491a11b8980b0546e43a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Diurno&lt;/div&gt;`)[0];
#                 popup_2cb099b22641a140e6094621bcdacba3.setContent(html_25d49b3d1517491a11b8980b0546e43a);
#
#
#
#         marker_56df55927a625f432d11dca1a4dbf720.bindPopup(popup_2cb099b22641a140e6094621bcdacba3)
#         ;
#
#
#
#
#                 marker_56df55927a625f432d11dca1a4dbf720.setIcon(icon_1dd048f03bb2dc114f09d9f0a34eacb3);
#
#
#             var marker_3a1e6a299e6f0f8484aabfae9fbfbbfa = L.marker(
#                 [-51.57546, -72.21239],
#                 {
# }
#             ).addTo(map_fd75e6bddaaf5f5173ff7df1521cb30c);
#
#
#             var icon_cc1e35cefc4df6f26e996f27f50387f5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2891706226af95bbe9f8d263d217237a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f609471d6404feeedfe6937ba7654d4c = $(`&lt;div id=&quot;html_f609471d6404feeedfe6937ba7654d4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nocturno&lt;/div&gt;`)[0];
#                 popup_2891706226af95bbe9f8d263d217237a.setContent(html_f609471d6404feeedfe6937ba7654d4c);
#
#
#
#         marker_3a1e6a299e6f0f8484aabfae9fbfbbfa.bindPopup(popup_2891706226af95bbe9f8d263d217237a)
#         ;
#
#
#
#
#                 marker_3a1e6a299e6f0f8484aabfae9fbfbbfa.setIcon(icon_cc1e35cefc4df6f26e996f27f50387f5);
#
#
#             var marker_d28f532ace0b0ee0026a398eb0baf3d5 = L.marker(
#                 [-51.57546, -72.21239],
#                 {
# }
#             ).addTo(map_fd75e6bddaaf5f5173ff7df1521cb30c);
#
#
#             var icon_8a0fb05fc41060434ec7c012279e3c1e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_98576d32ac906f54915048cf271f9e18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95dc650d1988eac26e0b1a8e41d7b56e = $(`&lt;div id=&quot;html_95dc650d1988eac26e0b1a8e41d7b56e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Diurno&lt;/div&gt;`)[0];
#                 popup_98576d32ac906f54915048cf271f9e18.setContent(html_95dc650d1988eac26e0b1a8e41d7b56e);
#
#
#
#         marker_d28f532ace0b0ee0026a398eb0ba

# %%
precio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36963 entries, 0 to 36962
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   indice_tiempo     36963 non-null  object
#  1   idempresa         36963 non-null  int64
#  2   cuit              36963 non-null  object
#  3   empresa           36963 non-null  object
#  4   direccion         36963 non-null  object
#  5   localidad         36963 non-null  object
#  6   provincia         36963 non-null  object
#  7   region            29128 non-null  object
#  8   idproducto        36963 non-null  int64
#  9   producto          36963 non-null  object
#  10  idtipohorario     36963 non-null  int64
#  11  tipohorario       36963 non-null  object
#  12  precio            36963 non-null  float64
#  13  fecha_vigencia    36963 non-null  object
#  14  idempresabandera  36963 non-null  int64
#  15  empresabandera    36963 non-null  object
#  16  latitud           36867 non-null  float64
#  17  longitud          36867 non-null  float64
#  18  geojson           36867 non-null  object
# dtypes: float64(3), int64(4), object(12)
# memory usage: 5.4+ MB

# %%
precio.head()
# Out:
#   indice_tiempo  idempresa           cuit               empresa  \
# 0       2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 1       2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 2       2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 3       2025-06       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 4       2025-05       1376  33-64337382-9  10 DE SETIEMBRE S.A.
#
#          direccion          localidad     provincia    region  idproducto  \
# 0  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          19
# 1  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          19
# 2  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          21
# 3  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          21
# 4  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA           6
#
#           producto  idtipohorario tipohorario  precio       fecha_vigencia  \
# 0  Gas Oil Grado 2              2      Diurno  1338.0  2025-06-21 09:41:00
# 1  Gas Oil Grado 2              3    Nocturno  1338.0  2025-06-21 09:41:00
# 2  Gas Oil Grado 3              2      Diurno  1552.0  2025-06-21 09:41:00
# 3  Gas Oil Grado 3              3    Nocturno  1552.0  2025-06-21 09:41:00
# 4              GNC              2      Diurno   499.9  2025-05-30 12:05:00
#
#    idempresabandera empresabandera    latitud   longitud  \
# 0                28           PUMA -34.658476 -58.529443
# 1                28           PUMA -34.658476 -58.529443
# 2                28           PUMA -34.658476 -58.529443
# 3                28           PUMA -34.658476 -58.529443
# 4                28           PUMA -34.658476 -58.529443
#
#                                              geojson
# 0  {"type":"Point","coordinates":[-58.529443,-34....
# 1  {"type":"Point","coordinates":[-58.529443,-34....
# 2  {"type":"Point","coordinates":[-58.529443,-34....
# 3  {"type":"Point","coordinates":[-58.529443,-34....
# 4  {"type":"Point","coordinates":[-58.529443,-34....

# %%
lugar=precio[precio['producto']=="Gas Oil Grado 2"]# eneste filtrar  de la columna produsto todos los datos igual gas
lugar["provincia"].value_counts()# despues lo guardo en la variable lugar y luego lo busco clos valores unicos de la columnas productos

# %%
precio["producto"].value_counts()
# Out:
# producto
# Gas Oil Grado 2                     8426
# Nafta (súper) entre 92 y 95 Ron     8400
# Gas Oil Grado 3                     8228
# Nafta (premium) de más de 95 Ron    8167
# GNC                                 3742
# Name: count, dtype: int64

# %%
precios_reb["producto"].min()
# Out:
# 'Gas Oil Grado 2'
